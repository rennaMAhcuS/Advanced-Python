# %% [markdown]
# # Matplotlib (Source: NeuralNine)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Scatter Plot

# %%
X_data_scatter_1 = np.random.random(50) * 100
Y_data_scatter_1 = np.random.random(50) * 100
plt.scatter(X_data_scatter_1, Y_data_scatter_1)

# %%
X_data_scatter_2 = np.random.random(500) * 100
Y_data_scatter_2 = np.random.random(500) * 100
plt.scatter(X_data_scatter_2, Y_data_scatter_2,
            color='#007BFF',
            s=80,  # Size
            marker='*',  # The datapoint marker
            alpha=0.2  # Transparency
            )

# %% [markdown]
# ## Line Graph

# %%
years_line = np.arange(2006, 2022)
weights_line = np.random.randint(60, 80, size=16)
plt.plot(years_line, weights_line,
         color='red',  # Line colour
         linestyle='--',
         linewidth=3
         )

# %% [markdown]
# ## Bar Chart

# %%
x_bar = np.array(["C++", "C#", "Python", "Java", "Go"])
y_bar = np.array([20, 50, 140, 5, 45])

plt.bar(x_bar, y_bar,
        color='red',
        align='center',  # The bar w.r.t the X - marker,
        width=0.5,
        edgecolor='lightblue', # Border
        linewidth=3  # Border
        )
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Histogram

# %%
ages_hist = np.random.normal(25, 2.5, 1000)
plt.hist(ages_hist,
         bins=40,  # Also supports an array
         color='red'
         )
# Out:
# (array([ 2.,  1.,  1.,  0.,  1.,  3.,  3.,  8.,  4., 12., 15., 15., 23.,
#         41., 41., 43., 42., 67., 61., 60., 49., 77., 52., 68., 68., 51.,
#         41., 28., 33., 19., 21., 11., 11.,  7.,  6.,  6.,  5.,  1.,  0.,
#          3.]),
#  array([16.71832857, 17.11167758, 17.5050266 , 17.89837562, 18.29172463,
#         18.68507365, 19.07842266, 19.47177168, 19.86512069, 20.25846971,
#         20.65181872, 21.04516774, 21.43851675, 21.83186577, 22.22521479,
#         22.6185638 , 23.01191282, 23.40526183, 23.79861085, 24.19195986,
#         24.58530888, 24.97865789, 25.37200691, 25.76535592, 26.15870494,
#         26.55205395, 26.94540297, 27.33875199, 27.732101  , 28.12545002,
#         28.51879903, 28.91214805, 29.30549706, 29.69884608, 30.09219509,
#         30.48554411, 30.87889312, 31.27224214, 31.66559116, 32.05894017,
#         32.45228919]),
#  <BarContainer object of 40 artists>)

# %%
# Cumulative Graph
plt.hist(ages_hist,
         bins=40,  # Also supports an array
         cumulative=True
         )
# Out:
# (array([   2.,    3.,    4.,    4.,    5.,    8.,   11.,   19.,   23.,
#           35.,   50.,   65.,   88.,  129.,  170.,  213.,  255.,  322.,
#          383.,  443.,  492.,  569.,  621.,  689.,  757.,  808.,  849.,
#          877.,  910.,  929.,  950.,  961.,  972.,  979.,  985.,  991.,
#          996.,  997.,  997., 1000.]),
#  array([16.71832857, 17.11167758, 17.5050266 , 17.89837562, 18.29172463,
#         18.68507365, 19.07842266, 19.47177168, 19.86512069, 20.25846971,
#         20.65181872, 21.04516774, 21.43851675, 21.83186577, 22.22521479,
#         22.6185638 , 23.01191282, 23.40526183, 23.79861085, 24.19195986,
#         24.58530888, 24.97865789, 25.37200691, 25.76535592, 26.15870494,
#         26.55205395, 26.94540297, 27.33875199, 27.732101  , 28.12545002,
#         28.51879903, 28.91214805, 29.30549706, 29.69884608, 30.09219509,
#         30.48554411, 30.87889312, 31.27224214, 31.66559116, 32.05894017,
#         32.45228919]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# ## Pie Chart
